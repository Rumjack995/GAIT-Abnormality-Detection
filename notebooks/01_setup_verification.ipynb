# %% [markdown]
# # Gait Abnormality Detection System - Setup Verification
#
# This notebook verifies that the development environment is properly set up and all dependencies are working correctly.

# %% [markdown]
# ## 1. Import Core Dependencies

# %%
# Core ML and Data Processing
import tensorflow as tf
import numpy as np
import pandas as pd

# Computer Vision
import cv2
import mediapipe as mp

# Scientific Computing
import scipy
from sklearn import __version__ as sklearn_version

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Testing
import pytest
import hypothesis

print("✓ All core dependencies imported successfully!")

# %% [markdown]
# ## 2. Check Versions

# %%
print("Dependency Versions:")
print(f"TensorFlow: {tf.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"OpenCV: {cv2.__version__}")
print(f"MediaPipe: {mp.__version__}")
print(f"SciPy: {scipy.__version__}")
print(f"Scikit-learn: {sklearn_version}")
print(f"Hypothesis: {hypothesis.__version__}")

# %% [markdown]
# ## 3. Test GPU Availability

# %%
# Check GPU availability
print("GPU Information:")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
print(f"Built with CUDA: {tf.test.is_built_with_cuda()}")

if tf.config.list_physical_devices('GPU'):
    gpu = tf.config.list_physical_devices('GPU')[0]
    print(f"GPU Device: {gpu}")
    
    # Test GPU memory
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
        print("✓ GPU memory growth enabled")
    except:
        print("⚠ Could not enable GPU memory growth")
else:
    print("⚠ No GPU detected - using CPU only")

# %% [markdown]
# ## 4. Test Project Imports

# %%
# Import our project modules
import gait_analysis
from gait_analysis.utils.config import get_config
from gait_analysis.utils.data_structures import ValidationResult, PoseKeypoint

print(f"✓ Gait Analysis package version: {gait_analysis.__version__}")
print("✓ Project modules imported successfully!")

# %% [markdown]
# ## 5. Test Configuration Loading

# %%
# Load and display configuration
config = get_config()

print("Configuration loaded successfully!")
print("\nVideo Processing Settings:")
for key, value in config.video_config.items():
    print(f"  {key}: {value}")

print("\nTraining Settings:")
for key, value in config.training_config.items():
    print(f"  {key}: {value}")

# %% [markdown]
# ## 6. Test MediaPipe Pose Detection

# %%
# Test MediaPipe pose detection setup
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Initialize pose detection
pose = mp_pose.Pose(
    static_image_mode=False,
    model_complexity=1,
    smooth_landmarks=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

print("✓ MediaPipe Pose initialized successfully!")
print(f"Number of pose landmarks: {len(mp_pose.PoseLandmark)}")

# %% [markdown]
# ## 7. Test Basic TensorFlow Operations

# %%
# Test basic TensorFlow operations
print("Testing TensorFlow operations...")

# Create a simple tensor
x = tf.constant([[1.0, 2.0], [3.0, 4.0]])
y = tf.constant([[2.0, 0.0], [0.0, 2.0]])

# Matrix multiplication
result = tf.matmul(x, y)
print(f"Matrix multiplication result:\n{result.numpy()}")

# Test if operations run on GPU (if available)
with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
    z = tf.reduce_sum(result)
    print(f"Sum result: {z.numpy()}")

print("✓ TensorFlow operations working correctly!")

# %% [markdown]
# ## 8. Summary

# %%
print("🎉 Development Environment Setup Complete!")
print("\n✅ All dependencies installed and working")
print("✅ Project structure created")
print("✅ Configuration system working")
print("✅ MediaPipe pose detection ready")
print("✅ TensorFlow operations functional")
print("\n🚀 Ready to start implementing gait analysis features!")
